# %% [markdown]
# ## Padronização pela normalização

# %%
import numpy as np
import pandas as pd

# %%
bova = [114.23,	113.80,112.58,112.23,111.94,111.66,111.27,113.08,113.32,112.18,112.34]
media_bova = np.mean(bova)

# %%
media_bova
# Out:
# 112.60272727272726

# %%
desvio_padrao = np.std(bova)

# %%
desvio_padrao
# Out:
# 0.8694312760659426

# %%
bova_normalizada =[]
for i in range(len(bova)):
  normalizado = (bova[i]-media_bova)/desvio_padrao
  bova_normalizada.append(round(normalizado,2))

# %%
bova_normalizada
# Out:
# [1.87, 1.38, -0.03, -0.43, -0.76, -1.08, -1.53, 0.55, 0.82, -0.49, -0.3]

# %%
def normaliza(dataframe):
  dataframe_normalizado= dataframe.copy()
  colunas = dataframe.columns[1:]
  for coluna in colunas:
    media = round(np.mean(dataframe_normalizado[coluna]),2)
    std = round(np.std(dataframe_normalizado[coluna]),4)
    dataframe_normalizado[coluna] = (dataframe_normalizado[coluna]-media)/std

  return dataframe_normalizado

# %%
data =["2020-01-02","2020-01-03","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-01-13","2020-01-14","2020-01-15","2020-01-16"]
bova = [114.23,	113.80,112.58,112.23,111.94,111.66,111.27,113.08,113.32,112.18,112.34]
fesa = [19.79,19.91,19.62,19.69,19.88,19.51,19.86,20.07,20.40,21.00,21.48]
grnd = [12.30,12.43,12.28,12.91,12.87,12.43,12.40,12.30,12.44,12.19,12.19]

dataframe = pd.DataFrame({"data":data,"BOVA":bova,"FESA":fesa,"GRND":grnd})

# %%
dataframe.head()
# Out:
#          data    BOVA   FESA   GRND
# 0  2020-01-02  114.23  19.79  12.30
# 1  2020-01-03  113.80  19.91  12.43
# 2  2020-01-06  112.58  19.62  12.28
# 3  2020-01-07  112.23  19.69  12.91
# 4  2020-01-08  111.94  19.88  12.87

# %%
dataframe_normalizado = round(normaliza(dataframe),2)

# %%
dataframe_normalizado.head()
# Out:
#          data  BOVA  FESA  GRND
# 0  2020-01-02  1.87 -0.55 -0.56
# 1  2020-01-03  1.38 -0.34  0.00
# 2  2020-01-06 -0.02 -0.83 -0.64
# 3  2020-01-07 -0.43 -0.72  2.06
# 4  2020-01-08 -0.76 -0.39  1.89

# %%
data =["2020-01-02","2020-01-03","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-01-13","2020-01-14","2020-01-15","2020-01-16"]
bova = [114.23,	113.80,112.58,112.23,111.94,111.66,111.27,113.08,113.32,112.18,112.34]
fesa = [19.79,19.91,19.62,19.69,19.88,19.51,19.86,20.07,20.40,21.00,21.48]
grnd = [12.30,12.43,12.28,12.91,12.87,12.43,12.40,12.30,12.44,12.19,12.19]

dataframe = pd.DataFrame({"data":data,"BOVA":bova,"FESA":fesa,"GRND":grnd})
dataframe.head()
# Out:
#          data    BOVA   FESA   GRND
# 0  2020-01-02  114.23  19.79  12.30
# 1  2020-01-03  113.80  19.91  12.43
# 2  2020-01-06  112.58  19.62  12.28
# 3  2020-01-07  112.23  19.69  12.91
# 4  2020-01-08  111.94  19.88  12.87

# %%
bova = dataframe["BOVA"].copy()

# %%
bova.head()
# Out:
# 0    114.23
# 1    113.80
# 2    112.58
# 3    112.23
# 4    111.94
# Name: BOVA, dtype: float64

# %%
media = round(np.mean(bova),2)
std = round(np.std(bova),4)

# %%
print(media)
print(std)
# Out:
# 112.6
# 0.8694

# %%
bova_normalizado = round((bova-media)/std,5)

# %%
bova_normalizado.head()
# Out:
# 0    1.87486
# 1    1.38026
# 2   -0.02300
# 3   -0.42558
# 4   -0.75914
# Name: BOVA, dtype: float64

# %%
print(f"""Média: {round(np.mean(bova_normalizado),2)}
 Desvio padrão:{round(np.std(bova_normalizado),2)}""")
# Out:
# Média: 0.0
#  Desvio padrão:1.0

# %%
def normaliza(dataframe):
  dataframe_normalizado = dataframe.copy()
  colunas = dataframe.columns[1:]
  for coluna in colunas:
    media = round(np.mean(dataframe_normalizado[coluna]),2)
    std = round(np.std(dataframe_normalizado[coluna]),4)
    dataframe_normalizado[coluna] = (dataframe_normalizado[coluna]-media)/std

  return dataframe_normalizado

# %%
def calcula(dataframe):
  colunas = dataframe.columns[1:]
  for coluna in colunas:
    print(f"""Ação: {coluna}
          Média: {round(np.mean(dataframe[coluna]),2)}
          Desvio padrão: {round(np.std(dataframe[coluna]),2)}""")

# %%
calcula(dataframe_normalizado)
# Out:
# Ação: BOVA
#           Média: 0.0
#           Desvio padrão: 1.0
# Ação: FESA
#           Média: -0.0
#           Desvio padrão: 1.0
# Ação: GRND
#           Média: 0.0
#           Desvio padrão: 1.0

# %% [markdown]
# ## Dimensionamento pela média

# %%
minimo = np.min(bova)
maximo = np.max(bova)
media = dataframe["BOVA"].mean()

# %%
normalizados =[]
for i in range(len(bova)):
 aux = (bova[i]-media)/(maximo-minimo)
 normalizados.append(round(aux,2))

# %%
def dimen_media(dataframe):
  dataframe_normalizado= dataframe.copy()
  colunas = dataframe.columns[1:]
  for coluna in colunas:
    media = round(np.mean(dataframe_normalizado[coluna]),2)
    min = dataframe[coluna].min()
    max = dataframe[coluna].max()
    dataframe_normalizado[coluna] = round((dataframe_normalizado[coluna]-media)/(max-min),2)

  return dataframe_normalizado

dataframe_norm = dimen_media(dataframe)

# %%
dataframe_norm.head()
# Out:
#          data  BOVA  FESA  GRND
# 0  2020-01-02  0.55 -0.16 -0.18
# 1  2020-01-03  0.41 -0.10  0.00
# 2  2020-01-06 -0.01 -0.25 -0.21
# 3  2020-01-07 -0.12 -0.21  0.67
# 4  2020-01-08 -0.22 -0.12  0.61

# %% [markdown]
# ## Padronização por min-max

# %%
minimo= np.min(bova)
maximo = np.max(bova)
min_max = maximo - minimo
padronizados =[]
for i in range(len(bova)):
  aux = (bova[i]-minimo)/(maximo-minimo)
  padronizados.append(round(aux,2))

# %%
def min_max(dataframe):
  dataframe_normalizado= dataframe.copy()
  colunas = dataframe.columns[1:]
  for coluna in colunas:
    min = dataframe_normalizado[coluna].min()
    max = dataframe_normalizado[coluna].max()
    dataframe_normalizado[coluna] = round((dataframe_normalizado[coluna]-min)/(max-min),2)

  return dataframe_normalizado

# %%
dataframe_min_max = min_max(dataframe)

# %%
dataframe_min_max.head()
# Out:
#          data  BOVA  FESA  GRND
# 0  2020-01-02  1.00  0.14  0.15
# 1  2020-01-03  0.85  0.20  0.33
# 2  2020-01-06  0.44  0.06  0.12
# 3  2020-01-07  0.32  0.09  1.00
# 4  2020-01-08  0.23  0.19  0.94

# %%
iqr = 113.32-111.94
iqr = 1.38

# %%
quantil1 = dataframe["BOVA"].quantile(0.25)
quantil2 = dataframe["BOVA"].quantile(0.75)

# %%
robusta = []
mediana_bova = np.median(bova)
for i in range(len(bova)):
  aux = (bova[i]-mediana_bova)/(quantil2-quantil1)
  robusta.append(round(aux,2))

# %%
def escala_robusta(dataframe):
  dataframe_copia= dataframe.copy()
  colunas = dataframe.columns[1:]
  for coluna in colunas:
    primeiro = dataframe_copia[coluna].quantile(0.25)
    terceiro = dataframe_copia[coluna].quantile(0.75)
    mediana = dataframe_copia[coluna].median()
    dataframe_copia[coluna] = round((dataframe_copia[coluna]-mediana)/(terceiro-primeiro),2)

  return dataframe_copia

# %%
dataframe_quantile = escala_robusta(dataframe)

# %%
dataframe_quantile.head()
# Out:
#          data  BOVA  FESA  GRND
# 0  2020-01-02  1.66 -0.18 -0.69
# 1  2020-01-03  1.28  0.06  0.21
# 2  2020-01-06  0.21 -0.53 -0.83
# 3  2020-01-07 -0.10 -0.38  3.52
# 4  2020-01-08 -0.35  0.00  3.24
